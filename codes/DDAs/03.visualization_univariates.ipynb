# %% [markdown]
# ## 단일 변수 시각화

# %%
import pandas as pd
df_LetalCars = pd.read_csv('../../datasets/LetalCarOfContractType.csv')
df_LetalCars.head(3)
# Out:
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0
# 2   우리은행           정상  60.0   2363.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl # 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'
mpl.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %% [markdown]
# ### 단일 변수

# %% [markdown]
# #### 수치형
# - 히스토그램 : 확률밀도분포 같이 작성 가능
# - boxplot : IQR(4분위 표시)

# %%
# df_LetalCars.describe()
df_LetalCars.describe().columns
# Out:
# Index(['id', 'Term', 'amount', 'overdue_count', 'credit rating', 'age',
#        'Mileage'],
#       dtype='object')

# %%
sns.histplot(data=df_LetalCars, x='age', kde=True) # kde - Kernal Density Estimation
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data = df_LetalCars, x = 'amount')
# Out:
# <Axes: xlabel='amount'>

# %% [markdown]
# #### 확률 밀도(kdeplot)

# %%
# 두개의 밀도의 하나의 그래프에 표현해서 비교
sns.kdeplot(data = df_LetalCars['Mileage']) 
sns.kdeplot(data = df_LetalCars['age'])
# Out:
# <Axes: xlabel='Mileage', ylabel='Density'>

# %% [markdown]
# #### 범주형

# %%
# df_LetalCars.describe(include='object')
df_LetalCars.describe(include='object').columns
# Out:
# Index(['type_of_contract', 'type_of_contract2', 'channel', 'datetime',
#        'payment_type', 'product', 'state', 'overdue', 'bank', 'cancellation'],
#       dtype='object')

# %%
sns.countplot(data = df_LetalCars, x = 'type_of_contract') # 세로로 나옴
# Out:
# <Axes: xlabel='type_of_contract', ylabel='count'>

# %%
sns.countplot(data = df_LetalCars, y = 'type_of_contract2') # 가로로 나옴
# Out:
# <Axes: xlabel='count', ylabel='type_of_contract2'>

# %% [markdown]
# #### 연습문제
# - 은행 중 거래가 가장 많은 은행 표시

# %%
df_LetalCars['bank'].value_counts() # 빈도수 그리기 가능
# Out:
# bank
# 국민은행         9901
# 롯데카드         9518
# 농협은행         6278
# 신한은행         3522
# 우리은행         3386
# 기업은행         1963
# 신한카드         1533
# 하나은행         1446
# 국민카드         1311
# BC카드         1264
# 새마을금고         964
# 부산은행          888
# 삼성카드          884
# 현대카드          876
# 대구은행          746
# 우체국           717
# 외환은행          586
# 외환카드          530
# 경남은행          442
# SC제일은행        439
# 광주은행          347
# 신협중앙회         341
# 전북은행          195
# 씨티은행          162
# 수협중앙회         160
# 제주은행           40
# 유안타증권          27
# 산업은행           23
# 현대증권           11
# 삼성증권            7
# 하나SK            6
# 미래에셋증권          5
# 신한금융투자          4
# NH농협카드          4
# 한국투자증권          4
# 우리카드            3
# 대우증권            2
# 상호저축은행          1
# 대신증권            1
# SK증권            1
# 하나대투증권          1
# 산림조합중앙회         1
# 수협카드            1
# 메리츠종합금융증권       1
# 하이투자증권          1
# 씨티카드            1
# Name: count, dtype: int64

# %%
sns.countplot(data = df_LetalCars, y = 'bank')
# Out:
# <Axes: xlabel='count', ylabel='bank'>

# %% [markdown]
# #### quests
# - 거래 가장 많은 상위 5위만 표시
# - 거래가 가장 적은 하위 5위만 표시

# %%
sns.countplot(data = df_LetalCars, y = 'bank')
# Out:
# <Axes: xlabel='count', ylabel='bank'>
